# %%
# https://onnx.ai/sklearn-onnx/index.html

# Train a model.
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestClassifier
iris = load_iris()
X, y = iris.data, iris.target
X_train, X_test, y_train, y_test = train_test_split(X, y)

print(X_train)

# clr = Ridge()
clr = RandomForestClassifier()
clr.fit(X_train, y_train)

# Convert into ONNX format
from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType
initial_type = [('float_input', FloatTensorType([None, 4]))]
onx = convert_sklearn(clr, initial_types=initial_type)

print(onx)

with open("rf_iris.onnx", "wb") as f:
    f.write(onx.SerializeToString())

# Compute the prediction with ONNX Runtime
import onnxruntime as rt
import numpy
sess = rt.InferenceSession("rf_iris.onnx")
input_name = sess.get_inputs()[0].name
label_name = sess.get_outputs()[0].name
pred_onx = sess.run([label_name], {input_name: X_test.astype(numpy.float32)})[0]

pred_onx

# another example
# http://onnx.ai/sklearn-onnx/auto_examples/plot_complex_pipeline.html
# Note: predictions don't match!
# Out:
# [[5.7 2.6 3.5 1. ]
#  [6.9 3.1 4.9 1.5]
#  [5.  3.3 1.4 0.2]
#  [6.3 2.9 5.6 1.8]
#  [5.8 2.7 3.9 1.2]
#  [5.6 2.8 4.9 2. ]
#  [6.3 2.3 4.4 1.3]
#  [7.7 3.  6.1 2.3]
#  [6.6 3.  4.4 1.4]
#  [6.6 2.9 4.6 1.3]
#  [5.1 2.5 3.  1.1]
#  [6.  3.4 4.5 1.6]
#  [5.6 2.9 3.6 1.3]
#  [4.8 3.  1.4 0.3]
#  [4.8 3.1 1.6 0.2]
#  [6.3 3.4 5.6 2.4]
#  [6.4 3.1 5.5 1.8]
#  [6.2 3.4 5.4 2.3]
#  [6.1 3.  4.6 1.4]
#  [5.5 3.5 1.3 0.2]
#  [5.  2.  3.5 1. ]
#  [5.1 3.5 1.4 0.2]
#  [5.4 3.7 1.5 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.5 2.3 1.3 0.3]
#  [5.5 2.3 4.  1.3]
#  [4.9 2.5 4.5 1.7]
#  [6.7 3.  5.2 2.3]
#  [5.  3.2 1.2 0.2]
#  [6.3 2.8 5.1 1.5]
#  [5.6 2.7 4.2 1.3]
#  [5.6 2.5 3.9 1.1]
#  [5.7 4.4 1.5 0.4]
#  [4.6 3.4 1.4 0.3]
#  [7.9 3.8 6.4 2. ]
#  [5.7 2.8 4.1 1.3]
#  [5.5 4.2 1.4 0.2]
#  [5.  2.3 3.3 1. ]
#  [4.9 3.1 1.5 0.2]
#  [6.4 3.2 4.5 1.5]
#  [6.7 3.  5.  1.7]
#  [5.8 2.7 5.1 1.9]
#  [7.7 2.8 6.7 2. ]
#  [5.3 3.7 1.5 0.2]
#  [4.6 3.6 1.  0.2]
#  [6.3 2.7 4.9 1.8]
#  [6.8 2.8 4.8 1.4]
#  [5.  3.6 1.4 0.2]
#  [6.1 2.8 4.  1.3]
#  [6.5 3.  5.5 1.8]
#  [5.5 2.4 3.8 1.1]
#  [4.9 3.6 1.4 0.1]
#  [5.2 3.4 1.4 0.2]
#  [6.7 3.3 5.7 2.5]
#  [6.  3.  4.8 1.8]
#  [5.  3.5 1.6 0.6]
#  [5.8 2.7 5.1 1.9]
#  [7.7 3.8 6.7 2.2]
#  [4.6 3.1 1.5 0.2]
#  [6.5 2.8 4.6 1.5]
#  [6.4 2.8 5.6 2.1]
#  [4.9 2.4 3.3 1. ]
#  [7.6 3.  6.6 2.1]
#  [5.5 2.4 3.7 1. ]
#  [5.1 3.5 1.4 0.3]
#  [4.8 3.  1.4 0.1]
#  [5.9 3.2 4.8 1.8]
#  [5.7 2.5 5.  2. ]
#  [7.  3.2 4.7 1.4]
#  [6.5 3.  5.8 2.2]
#  [5.1 3.8 1.5 0.3]
#  [7.1 3.  5.9 2.1]
#  [6.  2.2 4.  1. ]
#  [6.  2.2 5.  1.5]
#  [5.4 3.4 1.7 0.2]
#  [5.4 3.9 1.3 0.4]
#  [6.2 2.2 4.5 1.5]
#  [6.  2.9 4.5 1.5]
#  [7.3 2.9 6.3 1.8]
#  [5.1 3.7 1.5 0.4]
#  [5.5 2.5 4.  1.3]
#  [6.7 3.1 4.7 1.5]
#  [6.2 2.9 4.3 1.3]
#  [6.7 3.1 4.4 1.4]
#  [5.1 3.8 1.9 0.4]
#  [5.  3.4 1.6 0.4]
#  [7.2 3.  5.8 1.6]
#  [5.2 3.5 1.5 0.2]
#  [6.2 2.8 4.8 1.8]
#  [6.4 2.8 5.6 2.2]
#  [5.7 3.8 1.7 0.3]
#  [5.7 2.9 4.2 1.3]
#  [6.1 2.9 4.7 1.4]
#  [6.5 3.  5.2 2. ]
#  [6.3 3.3 4.7 1.6]
#  [6.7 3.3 5.7 2.1]
#  [6.8 3.2 5.9 2.3]
#  [7.2 3.6 6.1 2.5]
#  [4.4 3.2 1.3 0.2]
#  [5.7 3.  4.2 1.2]
#  [4.8 3.4 1.6 0.2]
#  [5.5 2.6 4.4 1.2]
#  [6.1 2.6 5.6 1.4]
#  [5.1 3.8 1.6 0.2]
#  [6.3 3.3 6.  2.5]
#  [5.4 3.9 1.7 0.4]
#  [7.4 2.8 6.1 1.9]
#  [5.1 3.3 1.7 0.5]
#  [6.7 3.1 5.6 2.4]
#  [4.6 3.2 1.4 0.2]
#  [6.1 3.  4.9 1.8]
#  [4.7 3.2 1.6 0.2]]
# ir_version: 4
# producer_name: "skl2onnx"
# producer_version: "1.8.0"
# domain: "ai.onnx"
# model_version: 0
# doc_string: ""
# graph {
#   node {
#     input: "float_input"
#     output: "label"
#     output: "probabilities"
#     name: "TreeEnsembleClassifier"
#     op_type: "TreeEnsembleClassifier"
#     attribute {
#       name: "class_ids"
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       ints: 0
#       ints: 1
#       ints: 2
#       type: INTS
#     }
#     attribute {
#       name: "class_nodeids"
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 15
#       ints: 15
#       ints: 15
#       ints: 16
#       ints: 16
#       ints: 16
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 15
#       ints: 15
#       ints: 15
#       ints: 16
#       ints: 16
#       ints: 16
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 15
#       ints: 15
#       ints: 15
#       ints: 16
#       ints: 16
#       ints: 16
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 16
#       ints: 16
#       ints: 16
#       ints: 17
#       ints: 17
#       ints: 17
#       ints: 18
#       ints: 18
#       ints: 18
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 15
#       ints: 15
#       ints: 15
#       ints: 16
#       ints: 16
#       ints: 16
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 15
#       ints: 15
#       ints: 15
#       ints: 16
#       ints: 16
#       ints: 16
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 15
#       ints: 15
#       ints: 15
#       ints: 17
#       ints: 17
#       ints: 17
#       ints: 18
#       ints: 18
#       ints: 18
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 15
#       ints: 15
#       ints: 15
#       ints: 17
#       ints: 17
#       ints: 17
#       ints: 18
#       ints: 18
#       ints: 18
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 15
#       ints: 15
#       ints: 15
#       ints: 16
#       ints: 16
#       ints: 16
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 15
#       ints: 15
#       ints: 15
#       ints: 16
#       ints: 16
#       ints: 16
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 17
#       ints: 17
#       ints: 17
#       ints: 18
#       ints: 18
#       ints: 18
#       ints: 19
#       ints: 19
#       ints: 19
#       ints: 20
#       ints: 20
#       ints: 20
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 13
#       ints: 13
#       ints: 13
#       ints: 14
#       ints: 14
#       ints: 14
#       ints: 2
#       ints: 2
#       ints: 2
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 11
#       ints: 11
#       ints: 11
#       ints: 12
#       ints: 12
#       ints: 12
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 4
#       ints: 4
#       ints: 4
#       ints: 5
#       ints: 5
#       ints: 5
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 9
#       ints: 9
#       ints: 9
#       ints: 10
#       ints: 10
#       ints: 10
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 3
#       ints: 3
#       ints: 3
#       ints: 6
#       ints: 6
#       ints: 6
#       ints: 7
#       ints: 7
#       ints: 7
#       ints: 8
#       ints: 8
#       ints: 8
#       ints: 1
#       ints: 1
#       ints: 1
#       ints: 3
#       ints: 3
# ...
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 1.6999999284744263
#       floats: 5.25
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 2.4499998092651367
#       floats: 0.0
#       floats: 1.75
#       floats: 7.0
#       floats: 5.049999713897705
#       floats: 1.4499999284744263
#       floats: 0.0
#       floats: 2.549999952316284
#       floats: 4.75
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 2.5999999046325684
#       floats: 0.0
#       floats: 1.75
#       floats: 5.299999713897705
#       floats: 2.25
#       floats: 4.75
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 3.1499998569488525
#       floats: 0.0
#       floats: 5.099999904632568
#       floats: 0.0
#       floats: 0.0
#       floats: 5.549999713897705
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 4.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 1.75
#       floats: 4.900000095367432
#       floats: 2.5
#       floats: 0.0
#       floats: 0.0
#       floats: 1.600000023841858
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 2.5999999046325684
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 1.649999976158142
#       floats: 0.0
#       floats: 4.650000095367432
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.699999988079071
#       floats: 0.0
#       floats: 6.149999618530273
#       floats: 4.75
#       floats: 1.649999976158142
#       floats: 0.0
#       floats: 0.0
#       floats: 5.849999904632568
#       floats: 0.0
#       floats: 5.199999809265137
#       floats: 3.0999999046325684
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 5.0
#       floats: 1.6999999284744263
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 5.449999809265137
#       floats: 2.700000047683716
#       floats: 0.0
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 2.5999999046325684
#       floats: 0.0
#       floats: 2.950000047683716
#       floats: 0.0
#       floats: 4.75
#       floats: 0.0
#       floats: 3.0999999046325684
#       floats: 0.0
#       floats: 0.0
#       floats: 1.649999976158142
#       floats: 2.9499998092651367
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 2.450000047683716
#       floats: 1.399999976158142
#       floats: 0.0
#       floats: 6.099999904632568
#       floats: 0.0
#       floats: 0.0
#       floats: 1.75
#       floats: 5.049999713897705
#       floats: 5.199999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 0.0
#       floats: 0.0
#       floats: 5.049999713897705
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 1.75
#       floats: 4.949999809265137
#       floats: 0.0
#       floats: 2.5999999046325684
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 5.449999809265137
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 0.0
#       floats: 1.5499999523162842
#       floats: 3.3499999046325684
#       floats: 4.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 6.099999904632568
#       floats: 0.0
#       floats: 0.0
#       floats: 6.599999904632568
#       floats: 0.0
#       floats: 6.75
#       floats: 3.1499998569488525
#       floats: 5.099999904632568
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 5.449999809265137
#       floats: 2.75
#       floats: 1.399999976158142
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 2.4499998092651367
#       floats: 0.0
#       floats: 0.0
#       floats: 1.75
#       floats: 2.8999998569488525
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 4.75
#       floats: 1.649999976158142
#       floats: 0.0
#       floats: 0.0
#       floats: 1.4499999284744263
#       floats: 6.449999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 2.4499998092651367
#       floats: 0.0
#       floats: 4.75
#       floats: 4.949999809265137
#       floats: 1.350000023841858
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 5.049999713897705
#       floats: 6.5
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 2.4499998092651367
#       floats: 0.0
#       floats: 1.649999976158142
#       floats: 1.3499999046325684
#       floats: 0.0
#       floats: 4.900000095367432
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 5.449999809265137
#       floats: 2.75
#       floats: 4.949999809265137
#       floats: 2.450000047683716
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 2.5
#       floats: 0.0
#       floats: 1.6999999284744263
#       floats: 0.0
#       floats: 3.0999999046325684
#       floats: 0.0
#       floats: 0.0
#       floats: 5.049999713897705
#       floats: 1.850000023841858
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 5.649999618530273
#       floats: 4.949999809265137
#       floats: 2.450000047683716
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 6.949999809265137
#       floats: 1.75
#       floats: 6.199999809265137
#       floats: 4.849999904632568
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 2.5
#       floats: 0.0
#       floats: 4.75
#       floats: 4.949999809265137
#       floats: 1.350000023841858
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 1.75
#       floats: 2.8999998569488525
#       floats: 0.0
#       floats: 5.400000095367432
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 4.75
#       floats: 1.600000023841858
#       floats: 0.0
#       floats: 0.0
#       floats: 6.599999904632568
#       floats: 4.849999904632568
#       floats: 5.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 1.75
#       floats: 0.0
#       floats: 0.0
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 6.049999713897705
#       floats: 1.649999976158142
#       floats: 0.0
#       floats: 3.0999999046325684
#       floats: 0.0
#       floats: 0.0
#       floats: 5.099999904632568
#       floats: 1.75
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 5.449999809265137
#       floats: 2.75
#       floats: 3.8999998569488525
#       floats: 2.1499998569488525
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 4.75
#       floats: 0.699999988079071
#       floats: 0.0
#       floats: 0.0
#       floats: 5.049999713897705
#       floats: 1.75
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 2.5999999046325684
#       floats: 0.0
#       floats: 4.75
#       floats: 4.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 1.75
#       floats: 5.299999713897705
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 5.449999809265137
#       floats: 2.4499998092651367
#       floats: 0.0
#       floats: 1.399999976158142
#       floats: 0.0
#       floats: 0.0
#       floats: 1.75
#       floats: 3.450000047683716
#       floats: 7.099999904632568
#       floats: 1.3499999046325684
#       floats: 0.0
#       floats: 6.199999809265137
#       floats: 2.75
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 6.0
#       floats: 4.849999904632568
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.699999988079071
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 4.949999809265137
#       floats: 0.0
#       floats: 1.6999999284744263
#       floats: 0.0
#       floats: 5.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 6.599999904632568
#       floats: 0.0
#       floats: 5.099999904632568
#       floats: 0.0
#       floats: 0.0
#       floats: 0.75
#       floats: 0.0
#       floats: 4.949999809265137
#       floats: 1.6999999284744263
#       floats: 0.0
#       floats: 5.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 7.049999713897705
#       floats: 5.949999809265137
#       floats: 4.849999904632568
#       floats: 4.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 6.549999713897705
#       floats: 4.75
#       floats: 0.0
#       floats: 0.0
#       floats: 2.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 2.4499998092651367
#       floats: 0.0
#       floats: 4.75
#       floats: 1.649999976158142
#       floats: 0.0
#       floats: 0.0
#       floats: 5.049999713897705
#       floats: 6.5
#       floats: 3.0999999046325684
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 1.600000023841858
#       floats: 5.900000095367432
#       floats: 0.0
#       floats: 2.6999998092651367
#       floats: 4.75
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 1.8499999046325684
#       floats: 3.0999999046325684
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 2.3499999046325684
#       floats: 0.0
#       floats: 1.75
#       floats: 4.949999809265137
#       floats: 0.0
#       floats: 5.049999713897705
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 1.5499999523162842
#       floats: 4.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 1.75
#       floats: 4.599999904632568
#       floats: 0.0
#       floats: 6.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 5.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.75
#       floats: 0.0
#       floats: 1.649999976158142
#       floats: 7.099999904632568
#       floats: 4.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 5.049999713897705
#       floats: 6.5
#       floats: 5.799999713897705
#       floats: 0.0
#       floats: 5.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.75
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 2.549999952316284
#       floats: 4.449999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 1.75
#       floats: 2.8999998569488525
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 1.6999999284744263
#       floats: 7.049999713897705
#       floats: 4.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 5.949999809265137
#       floats: 5.849999904632568
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 1.649999976158142
#       floats: 0.0
#       floats: 3.0999999046325684
#       floats: 0.0
#       floats: 0.0
#       floats: 1.75
#       floats: 1.649999976158142
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 2.4499998092651367
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 1.649999976158142
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.699999988079071
#       floats: 0.0
#       floats: 1.75
#       floats: 1.4499999284744263
#       floats: 0.0
#       floats: 5.049999713897705
#       floats: 5.449999809265137
#       floats: 0.0
#       floats: 2.5
#       floats: 6.099999904632568
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 3.0999999046325684
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 2.5999999046325684
#       floats: 0.0
#       floats: 1.649999976158142
#       floats: 4.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.75
#       floats: 0.0
#       floats: 4.75
#       floats: 0.0
#       floats: 1.75
#       floats: 5.049999713897705
#       floats: 2.5999999046325684
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 5.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 7.049999713897705
#       floats: 1.649999976158142
#       floats: 4.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 5.049999713897705
#       floats: 3.0999999046325684
#       floats: 6.5
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 5.449999809265137
#       floats: 2.5
#       floats: 0.0
#       floats: 2.450000047683716
#       floats: 0.0
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 0.6499999761581421
#       floats: 0.0
#       floats: 0.0
#       floats: 1.5499999523162842
#       floats: 6.5
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 2.5
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 1.6999999284744263
#       floats: 0.0
#       floats: 3.0
#       floats: 0.0
#       floats: 0.0
#       floats: 1.75
#       floats: 1.649999976158142
#       floats: 4.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 1.3499999046325684
#       floats: 0.0
#       floats: 4.849999904632568
#       floats: 1.6999999284744263
#       floats: 0.0
#       floats: 3.0999999046325684
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.800000011920929
#       floats: 0.0
#       floats: 6.25
#       floats: 2.450000047683716
#       floats: 1.399999976158142
#       floats: 0.0
#       floats: 0.0
#       floats: 5.0
#       floats: 0.0
#       floats: 5.75
#       floats: 1.649999976158142
#       floats: 0.0
#       floats: 0.0
#       floats: 4.699999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 5.0
#       floats: 1.6999999284744263
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 2.4499998092651367
#       floats: 0.0
#       floats: 1.649999976158142
#       floats: 7.049999713897705
#       floats: 4.949999809265137
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 1.8499999046325684
#       floats: 6.599999904632568
#       floats: 3.0999999046325684
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       floats: 0.0
#       type: FLOATS
#     }
#     attribute {
#       name: "post_transform"
#       s: "NONE"
#       type: STRING
#     }
#     domain: "ai.onnx.ml"
#   }
#   node {
#     input: "label"
#     output: "output_label"
#     name: "Cast"
#     op_type: "Cast"
#     attribute {
#       name: "to"
#       i: 7
#       type: INT
#     }
#     domain: ""
#   }
#   node {
#     input: "probabilities"
#     output: "output_probability"
#     name: "ZipMap"
#     op_type: "ZipMap"
#     attribute {
#       name: "classlabels_int64s"
#       ints: 0
#       ints: 1
#       ints: 2
#       type: INTS
#     }
#     domain: "ai.onnx.ml"
#   }
#   name: "efab1d06e8e34a9fb7650ea5c61b80fd"
#   input {
#     name: "float_input"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#           }
#           dim {
#             dim_value: 4
#           }
#         }
#       }
#     }
#   }
#   output {
#     name: "output_label"
#     type {
#       tensor_type {
#         elem_type: 7
#         shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
#   output {
#     name: "output_probability"
#     type {
#       sequence_type {
#         elem_type {
#           map_type {
#             key_type: 7
#             value_type {
#               tensor_type {
#                 elem_type: 1
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# opset_import {
#   domain: ""
#   version: 9
# }
# opset_import {
#   domain: "ai.onnx.ml"
#   version: 1
# }
# array([2, 2, 0, 0, 1, 2, 0, 0, 2, 2, 1, 0, 1, 0, 2, 0, 2, 1, 1, 1, 0, 2,
#        1, 1, 1, 0, 0, 2, 0, 1, 0, 2, 2, 2, 1, 2, 0, 2], dtype=int64)
